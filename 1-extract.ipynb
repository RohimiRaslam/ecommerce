# %%
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd

# %%
# options = webdriver.FirefoxOptions()
# options.add_argument('--headless')
search_url = f'https://www.amazon.com/'
# driver = webdriver.Firefox(options=options)
driver = webdriver.Firefox()

driver.get(search_url)
driver.find_element(By.XPATH , "//*[@id='twotabsearchtextbox']").send_keys('facial cleanser')
driver.find_element(By.XPATH , "//*[@id='nav-search-submit-button']").click()

# %%
product_names = []

results = driver.find_elements(By.XPATH , "//*[@class='a-size-base-plus a-color-base a-text-normal']")
for result in results:
    product_names.append(result.text)

# %%
product_urls = []

urls = driver.find_elements(By.XPATH , "//*[@class='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal']")
for url in urls:
    product_urls.append(url.get_attribute("href"))

# %%
prod_dict = {
    'Name': product_names,
    'Link': product_urls
}

df = pd.DataFrame(prod_dict)
df
# Out:
#                                                  Name  \
# 0   Amazon Basics Hydrating Facial Cleanser, 12 Fl...
# 1   Clean Skin Club Clean Towels XL™, 100% USDA Bi...
# 2   FOREO LUNA 4 Face Cleansing Brush -Firming Fac...
# 3   Kate Somerville Joy to the Glow ExfoliKate Set...
# 4   La Roche-Posay Toleriane Purifying Foaming Fac...
# 5   CeraVe SA Cleanser | Salicylic Acid Cleanser w...
# 6   Kiehl's Ultra Facial Cleanser, Lightweight Foa...
# 7   Jack Black Pure Clean Daily Facial Cleanser, 2...
# 8   Acure Brightening Cleansing Gel - Vegan Cleans...
# 9   Kiehl's Facial Fuel Face Wash, Refreshing + In...
# 10  IT Cosmetics Confidence in a Cleanser - Hydrat...
# 11  Lancôme Lait Galatėe Confort Facial Cleanser w...
# 12  Kiehl's Calendula Deep Cleansing Face Wash, Ba...
# 13  Lancôme Créme Mousse Confort Foaming Facial Cl...
# 14  Dermalogica Skin Resurfacing Cleanser - Dual-A...
# 15  Dermalogica Special Cleansing Gel Gentle-Foami...
# 16  Amazon Basics Morning Fresh Facial Cleanser wi...
# 17  Winner Disposable Face Towels | 100% USA Cotto...
# 18  Facial Cleansing Brush Face Scrubber Exfoliato...
# 19  Bamboo Rayon Disposable Face Towel Biodegradab...
# 20  Murad Clarifying Cleanser - Acne Control Salic...
# 21  Murad Essential-C Cleanser - Environmental Shi...
# 22  Curology Gentle Facial Cleanser, Lightly Foami...
# 23  Andalou Naturals Probiotic Cleansing Milk, Apr...
# 24  Face Towels Disposable Cotton Facial Clean Tow...
# 25  INNERNEED Super Soft Silicone Face Cleanser an...
# 26  Sud Scrub® Antimicrobial Silicone Face Scrubbe...
# 27  philosophy purity made simple one-step facial ...
# 28  Facial Cleansing Brush Electric Facial Exfolia...
# 29  CLn® Facial Cleanser - Hydrating Facial Cleans...
https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 17  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 18  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 19  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 20  https://www.amazon.com/Murad-Acne-Clarifying-C...
# 21  https://www.amazon.com/Murad-Environmental-Ess...
# 22  https://www.amazon.com/Curology-Cleanser-Light...
# 23  https://www.amazon.com/DEFYING-Apricot-Probiot...
# 24  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 25  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 26  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 27  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 28  https://www.amazon.com/Waterproof-Cleansing-Ex...
# 29  https://www.amazon.com/CLn-Facial-Cleanser-Sen...
# 30  https://www.amazon.com/Dermalogica-Breakout-Cl...
# 31  https://www.amazon.com/Principal-Secret-Reclai...
# 32  https://www.amazon.com/Resurfacing-Glycolic-Un...
# 33  https://www.amazon.com/Dermalogica-Active-Clea...
# 34  https://www.amazon.com/ACURE-Radically-Rejuven...
# 35  https://www.amazon.com/Hydrating-Cleanser-Mois...
# 36  https://www.amazon.com/Clean-Skin-Club-Disposa...
# 37  https://www.amazon.com/Mad-Hippie-Jelly-Cleans...
# 38  https://www.amazon.com/Kiehls-Exfoliating-Deto...
# 39  https://www.amazon.com/Kiehls-12989428601-Ultr...
# 40  https://www.amazon.com/Yes-Cucumbers-Cleanser-...
# 41  https://www.amazon.com/Jack-Black-Clay-Based-P...
# 42  https://www.amazon.com/CETAPHIL-Hydrating-Sens...
# 43  https://www.amazon.com/Clearasil-Rescue-Treatm...
# 44  https://www.amazon.com/Dermalogica-Precleanse-...
# 45  https://www.amazon.com/Black-Wolf-Nation-Activ...
# 46  https://www.amazon.com/Garnier-Light-Face-Wash...
# 47  https://www.amazon.com/Noxzema-Classic-Cleanse...
# 48  https://www.amazon.com/Kiehls-Cucumber-Herbal-...
# 49  https://www.amazon.com/ANUA-Double-Cleanser-Fa...
# 50  https://www.amazon.com/Acure-Seriously-Soothin...
# 51  https://www.amazon.com/CLn%C2%AE-Hypochlorite-...
# 52  https://www.amazon.com/Burts-Bees-Refreshing-H...
# 53  https://www.amazon.com/Murad-Clarifying-Cleans...
# 54  https://www.amazon.com/Dermalogica-Ultracalmin...
# 55  https://www.amazon.com/Alastin-Skincare-Gentle...
# 56  https://www.amazon.com/Murad-Control-Clarifyin...
# 57  https://www.amazon.com/Gentle-Kids-Foaming-Fac...
# 58  https://www.amazon.com/ELEMIS-Pro-Collagen-Ene...
# 59  https://www.amazon.com/Murad-Resurgence-Renewi...

# %%
product_prices = []

prices = driver.find_elements(By.TAG_NAME , "div")
for price in prices:
    harga = price.find_element(By.XPATH , "//span[@class='a-color-base']")
    print(harga.text)

product_prices
# Out:
# []
